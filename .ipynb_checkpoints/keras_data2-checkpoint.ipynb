# %% [markdown]
# ## Import requirements

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import tensorflow as tf

# %%
num_classes = 10
wspan= 50
hspan = 50
nhood = 1

# %% [markdown]
# # Build and train a model

# %%
### Load Data
data = np.load("./data/i0-0.8.npy")
#for i in range(8,9):
#    temp_data = np.load("./data/i0-0."+str(i)+".npy")
#    data=np.concatenate((data,temp_data),axis=0)

# %%
data=np.reshape(data,(len(data),30,50,50,1))
data.shape
# Out:
# (2000, 30, 50, 50, 1)

# %%
data[1000]
# Out:
# array([[[[1.],
#          [2.],
#          [7.],
#          ...,
#          [2.],
#          [7.],
#          [2.]],
#
#         [[2.],
#          [2.],
#          [1.],
#          ...,
#          [2.],
#          [2.],
#          [2.]],
#
#         [[2.],
#          [2.],
#          [2.],
#          ...,
#          [2.],
#          [2.],
#          [7.]],
#
#         ...,
#
#         [[2.],
#          [2.],
#          [2.],
#          ...,
#          [2.],
#          [2.],
#          [2.]],
#
#         [[2.],
#          [2.],
#          [1.],
#          ...,
#          [1.],
#          [2.],
#          [2.]],
#
#         [[2.],
#          [2.],
#          [2.],
#          ...,
#          [2.],
#          [2.],
#          [1.]]],
#
#
#        [[[2.],
#          [3.],
#          [8.],
#          ...,
#          [3.],
#          [8.],
#          [3.]],
#
#         [[3.],
#          [3.],
#          [2.],
#          ...,
#          [3.],
#          [3.],
#          [3.]],
#
#         [[3.],
#          [3.],
#          [3.],
#          ...,
#          [3.],
#          [3.],
#          [8.]],
#
#         ...,
#
#         [[3.],
#          [3.],
#          [3.],
#          ...,
#          [3.],
#          [3.],
#          [3.]],
#
#         [[3.],
#          [3.],
#          [2.],
#          ...,
#          [2.],
#          [3.],
#          [3.]],
#
#         [[3.],
#          [3.],
#          [3.],
#          ...,
#          [3.],
#          [3.],
#          [2.]]],
#
#
#        [[[3.],
#          [4.],
#          [9.],
#          ...,
#          [4.],
#          [9.],
#          [4.]],
#
#         [[4.],
#          [4.],
#          [3.],
#          ...,
#          [4.],
#          [4.],
#          [4.]],
#
#         [[4.],
#          [4.],
#          [4.],
#          ...,
#          [4.],
#          [4.],
#          [9.]],
#
#         ...,
#
#         [[4.],
#          [4.],
#          [4.],
#          ...,
#          [4.],
#          [4.],
#          [4.]],
#
#         [[4.],
#          [4.],
#          [3.],
#          ...,
#          [3.],
#          [4.],
#          [4.]],
#
#         [[4.],
#          [4.],
#          [4.],
#          ...,
#          [4.],
#          [4.],
#          [3.]]],
#
#
#        ...,
#
#
#        [[[2.],
#          [3.],
#          [4.],
#          ...,
#          [3.],
#          [2.],
#          [1.]],
#
#         [[3.],
#          [4.],
#          [5.],
#          ...,
#          [4.],
#          [3.],
#          [2.]],
#
#         [[4.],
#          [5.],
#          [6.],
#          ...,
#          [5.],
#          [4.],
#          [3.]],
#
#         ...,
#
#         [[0.],
#          [1.],
#          [0.],
#          ...,
#          [1.],
#          [0.],
#          [9.]],
#
#         [[9.],
#          [0.],
#          [9.],
#          ...,
#          [0.],
#          [9.],
#          [8.]],
#
#         [[8.],
#          [9.],
#          [8.],
#          ...,
#          [9.],
#          [8.],
#          [7.]]],
#
#
#        [[[3.],
#          [4.],
#          [5.],
#          ...,
#          [4.],
#          [3.],
#          [2.]],
#
#         [[4.],
#          [5.],
#          [6.],
#          ...,
#          [5.],
#          [4.],
#          [3.]],
#
#         [[5.],
#          [6.],
#          [7.],
#          ...,
#          [6.],
#          [5.],
#          [4.]],
#
#         ...,
#
#         [[1.],
#          [2.],
#          [1.],
#          ...,
#          [2.],
#          [1.],
#          [0.]],
#
#         [[0.],
#          [1.],
#          [0.],
#          ...,
#          [1.],
#          [0.],
#          [9.]],
#
#         [[9.],
#          [0.],
#          [9.],
#          ...,
#          [0.],
#          [9.],
#          [8.]]],
#
#
#        [[[4.],
#          [5.],
#          [6.],
#          ...,
#          [5.],
#          [4.],
#          [3.]],
#
#         [[5.],
#          [6.],
#          [7.],
#          ...,
#          [6.],
#          [5.],
#          [4.]],
#
#         [[6.],
#          [7.],
#          [8.],
#          ...,
#          [7.],
#          [6.],
#          [5.]],
#
#         ...,
#
#         [[2.],
#          [3.],
#          [2.],
#          ...,
#          [3.],
#          [2.],
#          [1.]],
#
#         [[1.],
#          [2.],
#          [1.],
#          ...,
#          [2.],
#          [1.],
#          [0.]],
#
#         [[0.],
#          [1.],
#          [0.],
#          ...,
#          [1.],
#          [0.],
#          [9.]]]])

# %%
temp_data=[]
for i in range(len(data)):
    for j in range(29):
        temp_data = temp_data[:] + [[data[i][j],data[i][j+1]]]
temp_data = np.array(temp_data)
temp_data.shape
# Out:
# (58000, 2, 50, 50, 1)

# %%
np.random.shuffle(temp_data)

# %%
### split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(temp_data[:,0], temp_data[:,1],test_size=0.2)

# %%
Y_train_onehot = tf.squeeze(tf.one_hot(tf.cast(Y_train, tf.int32), num_classes))
Y_test_onehot = tf.squeeze(tf.one_hot(tf.cast(Y_test, tf.int32), num_classes))

# %%
print(Y_train_onehot.shape)
#print(Y_test_onehot.shape)
# Out:
# (46400, 50, 50, 10)

# %%
### save train test arrays
np.save('X2_train.npy',X_train)
np.save('X2_test.npy',X_test)
np.save('Y2_train.npy',Y_train_onehot)
np.save('Y2_test.npy',Y_test_onehot)

# %%
### load train and test arrays
#80
#X_train = np.load('X_train.npy')
#20
X_train = np.load('X2_test.npy')
#20
#X_test = np.load('X_test.npy')
#80
#X_test = np.load('X_train.npy')
#80
#Y_train_onehot = np.load('Y_train_onehot.npy')
#20
#Y_train_onehot = np.load('Y_test_onehot.npy')
#20
#Y_test_onehot = np.load('Y_test_onehot.npy')
#80
#Y_test_onehot = np.load('Y_train_onehot.npy')
#80
#Y_train = np.load('Y_train.npy')
#20
Y_train_onehot = np.load('Y2_test.npy')
#80
#Y_test = np.load('Y_train.npy')
#20
#Y_test = np.load('Y_test.npy')

# %%
X_train.shape
# Out:
# (58000, 50, 50, 1)

# %%
#### Define and build model
tf.random.set_seed(0)
layer_dims = [100, 100, 100]
loss = lambda x, y : tf.keras.losses.categorical_crossentropy(tf.reshape(x, shape=(-1, num_classes)), 
                                                              tf.reshape(y, shape=(-1, num_classes)), 
                                    
                                                              from_logits=True)
diameter = 2*nhood+1
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer((wspan, hspan, 1)))
model.add(tf.keras.layers.Conv2D(layer_dims[0], kernel_size=[diameter, diameter], padding='same', 
                                 activation='relu', kernel_initializer=tf.keras.initializers.he_normal(), 
                                 bias_initializer=tf.keras.initializers.he_normal()))
for i in range(1, len(layer_dims)):
    model.add(tf.keras.layers.Dense(layer_dims[i],  activation='relu',
                                    kernel_initializer=tf.keras.initializers.he_normal(), 
                                    bias_initializer=tf.keras.initializers.he_normal()))
model.add(tf.keras.layers.Dense(num_classes,  activation='relu',
                                kernel_initializer=tf.keras.initializers.he_normal(), 
                                bias_initializer=tf.keras.initializers.he_normal()))

#model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-3), loss=loss,metrics=['accuracy'])
model.compile(optimizer=tf.keras.optimizers.SGD(lr=1e-1, nesterov=True), loss=loss,metrics=['accuracy'])

EPOCHS = 150
checkpoint_filepath = 'best_working_SGD_e-1_keras_data2_temp.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 50, 50, 100)       1000
# _________________________________________________________________
# dense_9 (Dense)              (None, 50, 50, 100)       10100
# _________________________________________________________________
# dense_10 (Dense)             (None, 50, 50, 100)       10100
# _________________________________________________________________
# dense_11 (Dense)             (None, 50, 50, 10)        1010
# =================================================================
# Total params: 22,210
# Trainable params: 22,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
###  Load model
#file='best_working_SGD_nesterov_e-1_kerastemp.h5'
file='best_working_SGD_e-1_keras_data2_temp.h5'
model.load_weights(file)

# %%
print(Y_test_onehot.shape)
# Out:
# (29000, 50, 50, 10)

# %%
#### Run training
train_history = model.fit(x=X_train, y=Y_train_onehot, epochs=100, batch_size=32,shuffle = True,verbose=1,validation_split=0.2,callbacks=[model_checkpoint_callback])
#train_history = model.fit(x=X_train, y=Y_train, epochs=EPOCHS, batch_size=14,shuffle = True,verbose=1,validation_split=0.2,callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/150
# 1160/1160 [==============================] - 28s 24ms/step - loss: 2.2175 - accuracy: 0.4567 - val_loss: 0.9412 - val_accuracy: 0.6978
# Epoch 2/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.9403 - accuracy: 0.6612 - val_loss: 1.0693 - val_accuracy: 0.5828
# Epoch 3/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.7636 - accuracy: 0.7282 - val_loss: 0.5337 - val_accuracy: 0.8589
# Epoch 4/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6772 - accuracy: 0.7584 - val_loss: 1.0582 - val_accuracy: 0.6138
# Epoch 5/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6368 - accuracy: 0.7814 - val_loss: 0.4563 - val_accuracy: 0.8696
# Epoch 6/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6554 - accuracy: 0.7801 - val_loss: 0.5378 - val_accuracy: 0.8482
# Epoch 7/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6779 - accuracy: 0.7672 - val_loss: 0.5216 - val_accuracy: 0.8339
# Epoch 8/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6667 - accuracy: 0.7700 - val_loss: 0.6031 - val_accuracy: 0.7684
# Epoch 9/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6002 - accuracy: 0.7884 - val_loss: 0.4591 - val_accuracy: 0.7834
# Epoch 10/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.5117 - accuracy: 0.8085 - val_loss: 0.3457 - val_accuracy: 0.8680
# Epoch 11/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.4635 - accuracy: 0.8272 - val_loss: 0.3707 - val_accuracy: 0.8572
# Epoch 12/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.5722 - accuracy: 0.8403 - val_loss: 0.8309 - val_accuracy: 0.6312
# Epoch 13/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.4450 - accuracy: 0.8410 - val_loss: 0.2846 - val_accuracy: 0.9083
# Epoch 14/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.4160 - accuracy: 0.8476 - val_loss: 0.2721 - val_accuracy: 0.9111
# Epoch 15/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3861 - accuracy: 0.8601 - val_loss: 0.2784 - val_accuracy: 0.9034
# Epoch 16/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3923 - accuracy: 0.8593 - val_loss: 0.2511 - val_accuracy: 0.9125
# Epoch 17/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3530 - accuracy: 0.8719 - val_loss: 0.2959 - val_accuracy: 0.8991
# Epoch 18/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3506 - accuracy: 0.8803 - val_loss: 0.2583 - val_accuracy: 0.9024
# Epoch 19/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3351 - accuracy: 0.8841 - val_loss: 0.2272 - val_accuracy: 0.9138
# Epoch 20/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.3389 - accuracy: 0.8813 - val_loss: 0.2179 - val_accuracy: 0.9140
# Epoch 21/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0
150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6468 - accuracy: 0.7875 - val_loss: 0.6360 - val_accuracy: 0.7908
# Epoch 129/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6465 - accuracy: 0.7863 - val_loss: 0.6365 - val_accuracy: 0.7908
# Epoch 130/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6482 - accuracy: 0.7852 - val_loss: 0.6358 - val_accuracy: 0.7908
# Epoch 131/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6469 - accuracy: 0.7859 - val_loss: 0.6358 - val_accuracy: 0.7908
# Epoch 132/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6474 - accuracy: 0.7855 - val_loss: 0.6357 - val_accuracy: 0.7908
# Epoch 133/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6494 - accuracy: 0.7863 - val_loss: 0.6357 - val_accuracy: 0.7908
# Epoch 134/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6431 - accuracy: 0.7865 - val_loss: 0.6356 - val_accuracy: 0.7908
# Epoch 135/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6393 - accuracy: 0.7880 - val_loss: 0.6355 - val_accuracy: 0.7908
# Epoch 136/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6463 - accuracy: 0.7862 - val_loss: 0.6354 - val_accuracy: 0.7908
# Epoch 137/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6411 - accuracy: 0.7879 - val_loss: 0.6354 - val_accuracy: 0.7908
# Epoch 138/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6416 - accuracy: 0.7885 - val_loss: 0.6354 - val_accuracy: 0.7908
# Epoch 139/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6494 - accuracy: 0.7859 - val_loss: 0.6356 - val_accuracy: 0.7908
# Epoch 140/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6427 - accuracy: 0.7872 - val_loss: 0.6353 - val_accuracy: 0.7908
# Epoch 141/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6437 - accuracy: 0.7868 - val_loss: 0.6353 - val_accuracy: 0.7908
# Epoch 142/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6459 - accuracy: 0.7861 - val_loss: 0.6353 - val_accuracy: 0.7908
# Epoch 143/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6409 - accuracy: 0.7877 - val_loss: 0.6352 - val_accuracy: 0.7908
# Epoch 144/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6419 - accuracy: 0.7879 - val_loss: 0.6354 - val_accuracy: 0.7908
# Epoch 145/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6453 - accuracy: 0.7872 - val_loss: 0.6352 - val_accuracy: 0.7908
# Epoch 146/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6453 - accuracy: 0.7865 - val_loss: 0.6352 - val_accuracy: 0.7908
# Epoch 147/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6435 - accuracy: 0.7870 - val_loss: 0.6352 - val_accuracy: 0.7908
# Epoch 148/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6439 - accuracy: 0.7864 - val_loss: 0.6351 - val_accuracy: 0.7908
# Epoch 149/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6469 - accuracy: 0.7866 - val_loss: 0.6352 - val_accuracy: 0.7908
# Epoch 150/150
# 1160/1160 [==============================] - 27s 23ms/step - loss: 0.6420 - accuracy: 0.7862 - val_loss: 0.6351 - val_accuracy: 0.7908

# %%
train_loss = train_history.history['loss'][:100] #+train_history1.history['loss'] 
val_loss = train_history.history['val_loss'][:100]#+train_history1.history['val_loss']
plt.plot(train_loss, 'k',label="training loss",color='green')
plt.plot(val_loss, 'k',label="validation loss",color='red')
plt.xlabel('epochs', fontsize=18)
plt.ylabel('loss', fontsize=16)
plt.legend()

# %%
### Evaluate the model
results = model.evaluate(X_test, Y_test_onehot, batch_size=32)
# Out:
# 363/363 [==============================] - 4s 11ms/step - loss: 1.2067 - accuracy: 0.9149

# %%
print("test loss, test accuracy : ",results)
# Out:
# test loss, test accuracy :  [1.2067060470581055, 0.9149383306503296]

# %%
X_test = X_test[..., tf.newaxis]
Y_test = Y_test[..., tf.newaxis]

# %%
labels = tf.argmax(tf.nn.softmax(model(X_test[:13])), axis=-1)
Y_pred = tf.reshape(labels, (-1, wspan, hspan))

# %%
### Plot results

## Generate testing data
#X_test = tf.convert_to_tensor(np.moveaxis(np.dstack([make_glider(10), make_glider(10)]), 2, 0), tf.float32)
# X_test = tf.convert_to_tensor(make_glider(10), tf.float32)[tf.newaxis, ...]
#Y_test = gol(X_test)
temp=1

tau_i = 4 
tau_r = 9
tau_0 = tau_i+tau_r

##Define discreet colormap
cmap = colors.ListedColormap(['xkcd:pale grey','xkcd:darkish red','xkcd:almost black'])
bounds = [0,0.99,tau_i+0.99,tau_0+0.99]
norm = colors.BoundaryNorm(bounds,cmap.N)

plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(tf.squeeze(X_test[temp]),cmap=cmap,norm=norm,interpolation='none')
plt.axis('off')
plt.title("Input")
print('input',X_test[temp].reshape(100,100))
plt.subplot(1,3,2)
plt.imshow(tf.squeeze(Y_test[temp]),cmap=cmap,norm=norm,interpolation='none')
plt.axis('off')
plt.title("Expected Output")
print('expected',Y_test[temp].reshape(100,100))
plt.subplot(1,3,3)
plt.imshow(tf.squeeze(Y_pred[temp]),cmap=cmap,norm=norm,interpolation='none')
plt.axis('off')
plt.title("Observed Output")
print('obswered',Y_pred[temp])
# Out:
# input [[8. 0. 8. ... 8. 0. 0.]
#  [0. 8. 8. ... 0. 0. 0.]
#  [8. 8. 0. ... 8. 8. 8.]
#  ...
#  [8. 8. 0. ... 8. 0. 8.]
#  [0. 0. 0. ... 0. 0. 8.]
#  [8. 8. 8. ... 8. 8. 0.]]
# expected [[9. 0. 9. ... 9. 0. 0.]
#  [0. 9. 9. ... 0. 0. 0.]
#  [9. 9. 0. ... 9. 9. 9.]
#  ...
#  [9. 9. 0. ... 9. 0. 9.]
#  [0. 0. 0. ... 0. 0. 9.]
#  [9. 9. 9. ... 9. 9. 0.]]
# obswered tf.Tensor(
# [[9 0 9 ... 9 0 0]
#  [0 9 9 ... 0 0 0]
#  [9 9 0 ... 9 9 9]
#  ...
#  [9 9 0 ... 9 0 9]
#  [0 0 0 ... 0 0 9]
#  [9 9 9 ... 9 9 0]], shape=(100, 100), dtype=int64)

# %%
### Save and load a model
model.save('keras_model1_data2.h5')
#del model
#model = tf.keras.models.load_model('path_to_my_model.h5', custom_objects={'Wraparound2D': Wraparound2D})

# %% [markdown]
# # Show activation patterns of hidden layers

# %%
import tensorflow.keras.backend as K

inp = model.input                                           # input placeholder
outputs = [layer.output for layer in model.layers]          # all layer outputs
functor = K.function(inp, outputs)   # evaluation function

layer_outs = functor([X_test, 1.])



# Plot activations of different neurons in different layers 
all_layer_activations = list()

min_max_scaler = lambda x : (x - np.min(x))/(np.max(x) - np.min(x))
# min_max_scaler = lambda x : (x - np.mean(x))
for j in range(1, 5):
    if j==1:
        layer_im = np.hstack([min_max_scaler(layer_outs[1][0][..., i]) for i in range(10)])
    else:
        pattern = np.reshape(layer_outs[j][0], (wspan, hspan, -1))
        layer_im = np.hstack([min_max_scaler(pattern[..., i]) for i in range(10)])
    all_layer_activations.append(layer_im)

        
plt.figure()
plt.imshow(np.vstack(all_layer_activations))
plt.title("Activations of hidden layers given \"Glider\" input")

plt.figure()
plt.imshow(np.squeeze(np.dstack(model.layers[1].weights[0].numpy())))
plt.title("Convolutional filters")
